# %%
# dependancies
import pandas as pd
import numpy as np

# %%
# file to load
year_2009_file = "Cleaned_Airlines_Data/2009_airlines_max_ARR_Delay.csv"

# Read Purchasing File and store into Pandas data frame
year_2009_fileDF = pd.read_csv(year_2009_file)

year_2009_fileDF
# Out:
#       Date of Flight Airline Identifier  Flight No. Origin Destination  \
# 0         2009-01-01                 WN          45    ABQ         DAL
# 1         2009-01-01                 WN        3190    ABQ         LAX
# 2         2009-01-01                 WN         413    ABQ         MAF
# 3         2009-01-01                 WN         109    BHM         BNA
# 4         2009-01-01                 WN         109    BNA         OAK
# ...              ...                ...         ...    ...         ...
# 58465     2009-12-31                 DL        1885    BWI         ATL
# 58466     2009-12-31                 DL        1990    MIA         ATL
# 58467     2009-12-31                 DL        2008    ATL         EWR
# 58468     2009-12-31                 DL        2015    EWR         ATL
# 58469     2009-12-31                 DL        2082    JFK         BOS
#
#        DEP_DELAY  ARR_DELAY  Date of Flight_month Date of Flight_weekday
# ...

# %%
# file to load
year_2018_file = "Cleaned_Airlines_Data/2018_airlines_max_ARR_Delay.csv"

# Read Purchasing File and store into Pandas data frame
year_2018_fileDF = pd.read_csv(year_2018_file)

year_2018_fileDF
# Out:
#        Date of Flight Airline Identifier  Flight No. Origin Destination  \
# 0          01/01/2018                 WN        1240    ABQ         HOU
# 1          01/01/2018                 WN         785    ABQ         SAN
# 2          01/01/2018                 WN        1769    ABQ         SAN
# 3          01/01/2018                 WN        2003    ALB         TPA
# 4          01/01/2018                 WN         414    AMA         LAS
# ...               ...                ...         ...    ...         ...
# 103218     12/31/2018                 DL        1514    DEN         SLC
# 103219     12/31/2018                 DL        1609    MSP         DEN
# 103220     12/31/2018                 DL        1624    MSP         ATL
# 103221     12/31/2018                 DL        1630    BIL         MSP
# 103222     12/31/2018                 DL        1630    MSP         BIL
#
#         DEP_DELAY  ARR_DELAY  Date of Flight_month Date of Flight_weekday
# ...
